# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
df = pd.read_csv("players_clean.csv")
df
# Out:
#        short_name                long_name  sofifa_id  age         dob  \
# 0      S. Blanaru           Stefan Blanaru     247999   30   2/20/1989
# 1         S. Fara              Stefan Fara     247894   18   4/23/2001
# 2         S. Rusu              Stefan Rusu     248421   19   1/21/2000
# 3    S. Târnovanu         Stefan Târnovanu     248073   19    5/9/2000
# 4      S. Vladoiu           Stefan Vladoiu     247949   20  12/28/1998
# ..            ...                      ...        ...  ...         ...
# 995    A. Mirante          Antonio Mirante     140293   35    7/8/1983
# 996      A. Miron             Andrei Miron     248002   25   5/28/1994
# 997    A. Mironov           Alexey Mironov     246254   19    1/1/2000
# 998    A. Mitrita  Alexandru Ionut Mitrita     229804   24    2/8/1995
# 999   A. Mitrovic      Aleksandar Mitrovic     215716   24   9/16/1994
#
#     nationality  height_cm body_type  weight_kg                   club  ...  \
# ...

# %%
df.head(5)
# Out:
#      short_name         long_name  sofifa_id  age         dob nationality  \
# 0    S. Blanaru    Stefan Blanaru     247999   30   2/20/1989     Romania
# 1       S. Fara       Stefan Fara     247894   18   4/23/2001     Romania
# 2       S. Rusu       Stefan Rusu     248421   19   1/21/2000     Romania
# 3  S. Târnovanu  Stefan Târnovanu     248073   19    5/9/2000     Romania
# 4    S. Vladoiu    Stefan Vladoiu     247949   20  12/28/1998     Romania
#
#    height_cm body_type  weight_kg                   club  ... player_traits  \
# 0        178    Normal         76        FC Hermannstadt  ...  Not Provided
# 1        181    Normal         77       Dinamo Bucuresti  ...  Not Provided
# 2        177    Normal         73       Politehnica Iasi  ...  Not Provided
# 3        197    Normal         81       Politehnica Iasi  ...  Not Provided
# 4        178    Normal         73  Universitatea Craiova  ...  Not Provided
#
# ...

# %%
sorted(df)
# Out:
# ['age',
#  'attacking_short_passing',
#  'body_type',
#  'club',
#  'defending',
#  'defending_sliding_tackle',
#  'defending_standing_tackle',
#  'dob',
#  'dribbling',
#  'height_cm',
#  'long_name',
#  'nationality',
#  'overall_potential',
#  'passing',
#  'player_traits',
#  'player_url',
#  'power_long_shots',
#  'power_shot_power',
#  'power_strength',
#  'shooting',
#  'short_name',
#  'skill_ball_control',
#  'skill_dribbling',
#  'skill_long_passing',
#  'sofifa_id',
#  'team_jersey_number',
#  'team_position',
#  'value_eur',
#  'wage_eur',
#  'weight_kg',
#  'work_rate']

# %%
df.shape
# Out:
# (1000, 31)

# %%
sorted_df = df.sort_values("short_name")
sorted_df
# Out:
#        short_name             long_name  sofifa_id  age         dob  \
# 8     A. Abdallah  Abdel Hakim Abdallah     237347   21   8/18/1997
# 9   A. Abdellaoui      Ayoub Abdellaoui     243896   26   2/16/1993
# 10   A. Abdennour       Aymen Abdennour     198076   29    8/6/1989
# 11        A. Abdi              Ali Abdi     252711   25  12/20/1993
# 12        A. Abdu            Ahmed Abdu     245438   22    8/8/1996
# ..            ...                   ...        ...  ...         ...
# 0      S. Blanaru        Stefan Blanaru     247999   30   2/20/1989
# 1         S. Fara           Stefan Fara     247894   18   4/23/2001
# 2         S. Rusu           Stefan Rusu     248421   19   1/21/2000
# 3    S. Târnovanu      Stefan Târnovanu     248073   19    5/9/2000
# 4      S. Vladoiu        Stefan Vladoiu     247949   20  12/28/1998
#
#      nationality  height_cm body_type  weight_kg                   club  ...  \
# ...
